# %%
import pandas as pd

# %%
df = pd.read_csv("data/Pass-Fail Data.csv")

# %%
print("Shape (rows, columns):", df.shape)

# %%
df.head()

# %%
print("Column names:")
print(df.columns)

print("\nData types:")
print(df.dtypes)
